# %%
import pandas as pd
import numpy as np
from sklearn import datasets, tree
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# ### 1.데이터 불러와서 지도학습에 필요한 특성정리

# %%
featuresData = pd.read_csv('../dataset/feature_regression_example.csv')

# %%
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %%
featuresData["HO_YN"] = np.where(featuresData["HOLIDAY"] == "Y", 1, 0)

# %%
featuresData["PRO_YN"] = np.where(featuresData["PROMOTION"] == "Y", 1, 0)

# %%
featuresData = featuresData[featuresData.YEARWEEK < 201652]

# %% [markdown]
# ### 2. 상관관계

# %%
corrDf = featuresData.corr()
corrDf
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT  \
# YEARWEEK     1.000000  0.956920  0.258352  0.129372 -0.057056     0.395384
# YEAR         0.956920  1.000000 -0.033272  0.039793  0.039730     0.313592
# WEEK         0.258352 -0.033272  1.000000  0.312927 -0.328588     0.317613
# QTY          0.129372  0.039793  0.312927  1.000000 -0.554981     0.720595
# HCLUS       -0.057056  0.039730 -0.328588 -0.554981  1.000000    -0.540038
# PRO_PERCENT  0.395384  0.313592  0.317613  0.720595 -0.540038     1.000000
# HO_YN        0.033300 -0.043522  0.259431  0.525317 -0.974338     0.480066
# PRO_YN       0.200441  0.191733  0.052028  0.622641 -0.370873     0.899430
#
#                 HO_YN    PRO_YN
# YEARWEEK     0.033300  0.200441
# YEAR        -0.043522  0.191733
# WEEK         0.259431  0.052028
# QTY          0.525317  0.622641
# HCLUS       -0.974338 -0.370873
# PRO_PERCENT  0.480066  0.899430
# HO_YN        1.000000  0.361723
# PRO_YN       0.361723  1.000000

# %%
corrResult = corrDf.reset_index()

# %%
featuresStd = 0.5

# %%
features = corrResult[(corrResult.QTY != 1)& (abs(corrResult.QTY) > featuresStd)]["index"].tolist()

# %%
features
# Out:
# ['HCLUS', 'PRO_PERCENT', 'HO_YN', 'PRO_YN']

# %%
label = ['QTY']

# %%
yearweekStd = 201630

# %%
trainingData_features = featuresData[featuresData.YEARWEEK <= yearweekStd][features]
trainingData_label = featuresData[featuresData.YEARWEEK <= yearweekStd][label]
testData_features = featuresData[featuresData.YEARWEEK > yearweekStd][features]
testData_label = featuresData[featuresData.YEARWEEK > yearweekStd]

# %% [markdown]
# ### 3.모델적용

# %%
model_method = tree.DecisionTreeClassifier()

# %%
model = model_method.fit(trainingData_features, trainingData_label)

# %%
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predict = model.predict(testData_features)

# %%
predict
# Out:
# array([ 973,  973,   16,  968,  968,  968,  973,  973,  973,  973, 1172,
#         973,   16, 2033, 2033, 2033, 2033, 2033,  973,  973,  973],
#       dtype=int64)

# %% [markdown]
# ### 4. 데이터 정리

# %%
predictData = pd.DataFrame(predict)
predictData
# Out:
#        0
# 0    973
# 1    973
# 2     16
# 3    968
# 4    968
# 5    968
# 6    973
# 7    973
# 8    973
# 9    973
# 10  1172
# 11   973
# 12    16
# 13  2033
# 14  2033
# 15  2033
# 16  2033
# 17  2033
# 18   973
# 19   973
# 20   973

# %%
predictData.columns = ["PREDICT"]

# %%
testData_label = testData_label.reset_index(drop = True)

# %%
AnswerData = pd.concat([testData_label,predictData],axis = 1, )

# %%
AnswerData
# Out:
#     index        REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  \
# 0      83  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016
# 1      84  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016
# 2      85  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016
# 3      86  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016
# 4      87  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016
# 5      88  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016
# 6      89  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016
# 7      90  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016
# 8      91  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016
# 9      92  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016
# 10     93  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016
# 11     94  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016
# 12     95  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016
# 13     96  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016
# 14     97  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016
# 15     98  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016
# 16     99  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016
# 17    100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016
# 18    101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016
# 19    102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016
# 20    103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016
#
#     WEEK   QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN  PREDICT
# 0     31  1522       N      4         Y     0.280258      0       1      973
# 1     32  2100       N      4         Y     0.280258      0       1      973
# 2     33    43       N      4         N     0.000000      0       0       16
# 3     34  1700       Y      1         Y     0.308584      1       1      968
# 4     35  1514       Y      1         Y     0.308584      1       1      968
# 5     36  1501       Y      1         Y     0.308584      1       1      968
# 6     37  1491       N      4         Y     0.308584      0       1      973
# 7     38   806       N      4         Y     0.308584      0       1      973
# 8     39  2111       N      4         Y     0.280258      0       1      973
# 9     40  2400       N      4         Y     0.280258      0       1      973
# 10    41  2010       Y      2         Y     0.280258      1       1     1172
# 11    42  1900       N      4         Y     0.280258      0       1      973
# 12    43   141       N      4         N     0.000000      0       0       16
# 13    44  1615       Y      0         Y     0.421888      1       1     2033
# 14    45  1574       Y      0         Y     0.421888      1       1     2033
# 15    46  1800       Y      0         Y     0.421888      1       1     2033
# 16    47  2600       Y      0         Y     0.421888      1       1     2033
# 17    48  2412       Y      0         Y     0.421888      1       1     2033
# 18    49  1955       N      4         Y     0.421888      0       1      973
# 19    50  1800       N      4         Y     0.352361      0       1      973
# 20    51  1173       N      4         Y     0.352361      0       1      973

# %%
mean_absolute_error(AnswerData['QTY'], AnswerData['PREDICT'])
# Out:
# 605.6666666666666

# %%
mean_squared_error(AnswerData['QTY'], AnswerData['PREDICT'])
# Out:
# 499435.6666666667

# %%
r2_score(AnswerData['QTY'], AnswerData['PREDICT'])
# Out:
# -0.2095683544140019

# %% [markdown]
# ### pivotTable

# %%
pivotResult = AnswerData. \
pivot_table(index = ["HO_YN", "PRO_YN"],
           columns = "YEARWEEK", values = "PREDICT")
pivotResult2 = pivotResult.reset_index()
pivotResult2
# Out:
# YEARWEEK  HO_YN  PRO_YN  201631  201632  201633  201634  201635  201636  \
# 0             0       0     NaN     NaN    16.0     NaN     NaN     NaN
# 1             0       1   973.0   973.0     NaN     NaN     NaN     NaN
# 2             1       1     NaN     NaN     NaN   968.0   968.0   968.0
#
# YEARWEEK  201637  201638   ...    201642  201643  201644  201645  201646  \
# 0            NaN     NaN   ...       NaN    16.0     NaN     NaN     NaN
# 1          973.0   973.0   ...     973.0     NaN     NaN     NaN     NaN
# 2            NaN     NaN   ...       NaN     NaN  2033.0  2033.0  2033.0
#
# YEARWEEK  201647  201648  201649  201650  201651
# 0            NaN     NaN     NaN     NaN     NaN
# 1            NaN     NaN   973.0   973.0   973.0
# 2         2033.0  2033.0     NaN     NaN     NaN
#
# [3 rows x 23 columns]
