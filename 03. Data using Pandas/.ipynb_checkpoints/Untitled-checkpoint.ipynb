# %%
import pandas as pd

# %%
selloutData = pd.read_csv('../dataset/kopo_channel_seasonality_new.csv')
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
selloutData["YEARWEEK"] = selloutData.YEARWEEK.astype(str)

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# dtype: object

# %%
import numpy as np

# %%
selloutDataC = selloutData[["REGIONID","PRODUCT"]]
selloutDataC.head(2)
# Out:
#   REGIONID    PRODUCT
# 0      A60   PRODUCT4
# 1      A60  PRODUCT59

# %%
csDataF = pd.read_csv('../dataset/kopo_customerdata.csv')
csDataF.head()
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
csDataC = csDataF[["CUSTOMERCODE","STATENAME","GENDER","EMAIL"]]
csDataC.head()
# Out:
#    CUSTOMERCODE STATENAME  GENDER  EMAIL
# 0       1503989    State2    Male      1
# 1       1190338    State2    Male      0
# 2       1424715    State2  Female      0
# 3       2483305    State2    Male      0
# 4       1178802    State2    Male      0

# %%
indexS = csDataF.iloc[0:6,5:8]
indexS
# Out:
#    GENDER1  EMAIL  FEST_CNT
# 0        1      1         0
# 1        1      0         1
# 2        2      0         0
# 3        1      0         1
# 4        1      0         1
# 5        1      0         0

# %%
csDataCol = csDataF.columns
