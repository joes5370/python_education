# %%
import pandas as pd
customerdata = pd.read_csv('../dataset/customerdata.csv')
customerdata.head(5)
# Out:
#    Unnamed: 0  CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE  \
# 0           0  A13566  4273.900000    3          6.4    1.679181
# 1           1  A14219  3642.441950    2          4.0    2.682023
# 2           2  A15312  3653.884565    2          5.0    3.208202
# 3           3  A16605  3713.211107    2          6.6    0.900000
# 4           4  B10634  3391.074215    2          4.2    2.453656
#
#           CUSTTYPE2
# 0  Big-Screen-lover
# 1      Sleeping-dog
# 2      Sleeping-dog
# 3        Early-bird
# 4      Sleeping-dog

# %%
customerdata.dtypes
# Out:
# Unnamed: 0       int64
# CUSTID          object
# AVGPRICE       float64
# EMI              int64
# DEVICECOUNT    float64
# PRODUCTAGE     float64
# CUSTTYPE2       object
# dtype: object

# %%
customerdata["EMI"] = customerdata["EMI"].astype(int)##astype can change types
print(customerdata.dtypes)
# Out:
# Unnamed: 0       int64
# CUSTID          object
# AVGPRICE       float64
# EMI              int32
# DEVICECOUNT    float64
# PRODUCTAGE     float64
# CUSTTYPE2       object
# dtype: object

# %%
customerdata1 = customerdata[ (customerdata.EMI == 2) & (customerdata.PRODUCTAGE >=3)]
customerdata1
# Out:
#      Unnamed: 0  CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE  \
# 2             2  A15312  3653.884565    2          5.0    3.208202
# 9             9  C15050  4020.173425    2          4.9    3.013440
# 10           10  C18306  4005.005142    2          4.7    3.113618
# 14           14  D13030  3227.855655    2          4.8    3.467370
# 28           28  F18646  3334.244233    2          4.5    3.273196
# 31           31  G15439  3559.617754    2          4.5    3.345695
# 32           32  G15736  3624.700000    2          5.7    3.367229
# 89           89  Q18901  3266.600816    2          5.1    3.016625
# 101         101  S14751  3137.800000    2          5.1    3.326340
# 114         114  T11512  3428.518977    2          4.7    3.483573
# 118         118  U15861  3975.963499    2          4.5    3.292546
# 123         123  V10654  3902.329790    2          4.6    3.260149
#
#             CUSTTYPE2
# 2        Sleeping-dog
# 9        Sleeping-dog
# 10       Sleeping-dog
# ...

# %%
import pandas as pd
aa = pd.read_csv('../dataset/kopo_product_volume.csv')
aa.head(4)
# Out:
#   REGIONID PRODUCTGROUP  YEARWEEK  VOLUME
# 0      A01       ST0001    201415  810144
# 1      A01       ST0002    201415  128999
# 2      A01       ST0001    201418  671464
# 3      A01       ST0002    201418  134467

# %%
yearweek = 201415

# %%
productgroup = "st0001"
productgroup = productgroup.upper()

# %%
answer = aa[ (aa.PRODUCTGROUP.str.upper == productgroup ) & (aa.VOLUME > 30000)]
answer.head(4)
# Out:
# Empty DataFrame
# Columns: [REGIONID, PRODUCTGROUP, YEARWEEK, VOLUME]
# Index: []
