# %%
import pandas as pd

# %%
customerData = pd.read_csv('./dataset/kopo_customerdata.csv')
customerData = pd.DataFrame(customerData)
customerData.head()
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
dd = pd.read_csv('./dataset/customerdata.csv')
dd.head()
# Out:
#    Unnamed: 0  CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE  \
# 0           0  A13566  4273.900000    3          6.4    1.679181
# 1           1  A14219  3642.441950    2          4.0    2.682023
# 2           2  A15312  3653.884565    2          5.0    3.208202
# 3           3  A16605  3713.211107    2          6.6    0.900000
# 4           4  B10634  3391.074215    2          4.2    2.453656
#
#           CUSTTYPE2
# 0  Big-Screen-lover
# 1      Sleeping-dog
# 2      Sleeping-dog
# 3        Early-bird
# 4      Sleeping-dog

# %%
Answer = customerData[(customerData.GENDER == "Male") & (customerData.EMAIL > 0)]
Answer.head()
# Out:
#      CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0         1503989    State2   2   Male    0        1      1         0
# 16        1154228    State2   2   Male    0        1      1         0
# 81         393246    State2   2   Male    0        1      1         1
# 206       2532568    State2   2   Male    1        1      1         0
# 216        487928    State2   2   Male    0        1      1         0
#
#      TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0           30300          0      30300          0              0           0
# 16          18200          0          0      18200              0           0
# 81          18200          0          0      18200              0           0
# 206         48000      48000          0          0              0           0
# 216         72300          0      27900      44400              0           0
#
#      CNT_VIST  GAP_VISIT
# 0           1          0
# ...

# %%
selloutData = pd.read_csv('./dataset/kopo_channel_seasonality_new.csv')
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# dtype: object

# %%
s = selloutData.astype(str)
s["QTY"] = selloutData["QTY"].astype(float)
s.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK     object
# QTY         float64
# dtype: object

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# dtype: object

# %%
dd1 = dd.iloc[0:1,:]
            ##행 열
dd1
# Out:
#    Unnamed: 0  CUSTID  AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE  \
# 0           0  A13566    4273.9    3          6.4    1.679181
#
#           CUSTTYPE2
# 0  Big-Screen-lover

# %%
dd2 = dd.loc[0:2,["CUSTID","AVGPRICE"]]
            ##행 2전까지 , 열
dd2
# Out:
#    CUSTID     AVGPRICE
# 0  A13566  4273.900000
# 1  A14219  3642.441950
# 2  A15312  3653.884565
