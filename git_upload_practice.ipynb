# %%
a=3
b=6
print(a+b)
# Out:
# 9

# %%
import numpy as np
np.linspace(1,100,num=20)
# Out:
# array([  1.        ,   6.21052632,  11.42105263,  16.63157895,
#         21.84210526,  27.05263158,  32.26315789,  37.47368421,
#         42.68421053,  47.89473684,  53.10526316,  58.31578947,
#         63.52631579,  68.73684211,  73.94736842,  79.15789474,
#         84.36842105,  89.57894737,  94.78947368, 100.        ])

# %%
import numpy as np
np.random.rand(20)*5
# Out:
# array([2.67252516, 2.42432305, 2.89688994, 4.08381249, 1.58228457,
#        4.53823815, 2.94305213, 3.72343158, 3.38707302, 0.25581471,
#        3.42175644, 4.18994676, 3.5399713 , 1.5088378 , 2.7410826 ,
#        2.94466103, 4.27372763, 1.14373275, 0.18593269, 1.90714848])

# %%
import pandas as pd
pd.read_csv('./Python_ST_EX/dataset/bmi.csv')
# Out:
#        height  weight   label
# 0         140      45  normal
# 1         145      72     fat
# 2         150      61     fat
# 3         137      56     fat
# 4         192      48    thin
# 5         175      77     fat
# 6         127      39  normal
# 7         152      38    thin
# 8         184      38    thin
# 9         186      41    thin
# 10        188      60    thin
# 11        181      43    thin
# 12        200      75  normal
# 13        146      65     fat
# 14        198      54    thin
# 15        133      70     fat
# 16        188      80  normal
# 17        156      49  normal
# 18        200      63    thin
# 19        182      64  normal
# 20        139      60     fat
# 21        134      57     fat
# 22        123      48     fat
# 23        164      65  normal
# 24        136      44  normal
# 25        184      68  normal
# 26        187      64    thin
# 27        194      71  normal
# 28        189      65    thin
# 29        141      56     fat
# ...

# %%
pwd
# Out:
# 'C:\\Users\\SMART-24\\Python_FinTech'
